# %%
v1:int = 50
print(type(v1))
# Out:
# <class 'int'>

# %%
v1 = 100
print(type(v1))
# Out:
# <class 'int'>

# %%
v2: float = 50.0
v3: bool = True
v4: str = "hello!"

# %%
def get_full_name(first_name: str, last_name: str) -> str:
    full_name: str = first_name.title() + " " + last_name.title()
    return full_name

# %%
def get_name_with_age(name: str, age: int) -> str:
    name_with_age = name + "is this old:" + str(age)
    return name_with_age

# %%
### 容器行別提示(collection Type Hints)

# %%
names: list[str] = ["alice","bob"]

# %%
from typing import List
names1:List[str] = ["愛麗絲", "鮑伯"]

# %%
prices:dict[str, float] = {"蘋果": 35.0, "香蕉": 15.5}

# %%
def process_items(items:list[str]) -> None:
    for item in items:
        print(item.upper())

# %%
def print_prices(prices:dict[str, float]) -> None:
    for item_name, item_price in prices.items():
        print(f"商品:{item_name}, 價格:{item_price}")

# %%
def process_(items_t:tuple[int,int,str], items_s:set[bytes]) -> tuple[tuple[int,int,str],set[bytes]]:
    return items_t , items_s

# %%
### 複合與可選型別提示(Union & optioanal)

# %%
def process_item(item: int | str) -> None:
    print(f"處理資料:{item}")

from typing import Union
def process_item1(item:Union[int, str]) -> None:
    print(item)

# %%
def say_hi(name: str | None = None) -> None:
    if name is None:
        print("哈囉，世界")
    else:
        print(f"Hello! {name}")
say_hi()
say_hi("robert")
# Out:
# 哈囉，世界
# Hello! robert

# %%
from typing import Optional
def say_hi1(name: Optional[str] = None) -> None:
    if name is None:
        print("哈囉，世界")
    else:
        print(f"Hello! {name}")
say_hi1()
say_hi1("robert")

# %%
class Person(object):
    def __init__(self, name:str):
        self.name = name

john: Person = Person(name="john")

def get_person_name(one_person: Person) -> str:
    return one_person.name

get_person_name(john)
# Out:
# 'john'
